# %% [markdown]
# <a href="https://colab.research.google.com/github/Adithyasajeev22/Deep-Learning/blob/main/FNN_(REGRESSION)_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **FNN REGRESSION**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/flood_prediction_dataset.csv')
df.head(5)
# Out:
#    Rainfall_mm  River_Level_m  Soil_Moisture_%  Temperature_C  Humidity_%  \
# 0   224.835708     130.663828        64.058239      29.282884   98.450004
# 1   193.086785     111.317930        56.398538      29.836720   91.450593
# 2   232.384427     121.474224        66.728423      30.321474   87.111687
# 3   276.151493     162.389994        83.397538      34.734307  111.026141
# 4   188.292331     120.303690        62.473592      26.263913   72.757639
#
#    Wind_Speed_kmh  Drainage_Capacity  Elevation_m Region   Season  \
# 0       10.512621          40.291420          NaN   West   Summer
# 1       10.036766          54.175215   462.448719   West  Monsoon
# 2        8.706535          61.194574   334.551727   East  Monsoon
# 3        9.992420          72.245034   274.487904  South   Winter
# 4       11.472525          85.362435   193.327518   West  Monsoon
#
#    Flood_Risk_Index  Previous_Floods
# 0        112.651460              1.0
# 1        108.693955              0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5250 entries, 0 to 5249
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rainfall_mm        5146 non-null   float64
#  1   River_Level_m      5145 non-null   float64
#  2   Soil_Moisture_%    5144 non-null   float64
#  3   Temperature_C      5145 non-null   float64
#  4   Humidity_%         5146 non-null   float64
#  5   Wind_Speed_kmh     5146 non-null   float64
#  6   Drainage_Capacity  5146 non-null   float64
#  7   Elevation_m        5143 non-null   float64
#  8   Region             5146 non-null   object
#  9   Season             5143 non-null   object
#  10  Flood_Risk_Index   5148 non-null   float64
#  11  Previous_Floods    5144 non-null   float64
# dtypes: float64(10), object(2)
# memory usage: 492.3+ KB

# %%
df.isnull().sum()
# Out:
# Rainfall_mm          104
# River_Level_m        105
# Soil_Moisture_%      106
# Temperature_C        105
# Humidity_%           104
# Wind_Speed_kmh       104
# Drainage_Capacity    104
# Elevation_m          107
# Region               104
# Season               107
# Flood_Risk_Index     102
# Previous_Floods      106
# dtype: int64

# %%
df['Rainfall_mm'].hist()
# Out:
# <Axes: >

# %%
df['River_Level_m'].hist()
# Out:
# <Axes: >

# %%
df['Soil_Moisture_%'].hist()
# Out:
# <Axes: >

# %%
df['Temperature_C'].hist()
# Out:
# <Axes: >

# %%
df['Humidity_%'].hist()
# Out:
# <Axes: >

# %%
df['Wind_Speed_kmh'].hist()
# Out:
# <Axes: >

# %%
df['Drainage_Capacity'].hist()
# Out:
# <Axes: >

# %%
df['Elevation_m'].hist()
# Out:
# <Axes: >

# %%
df['Flood_Risk_Index'].hist()
# Out:
# <Axes: >

# %%
df['Rainfall_mm'].fillna(df['Rainfall_mm'].median(),inplace=True)
df['River_Level_m'].fillna(df['River_Level_m'].median(),inplace=True)
df['Soil_Moisture_%'].fillna(df['Soil_Moisture_%'].median(),inplace=True)
df['Temperature_C'].fillna(df['Temperature_C'].median(),inplace=True)
df['Humidity_%'].fillna(df['Humidity_%'].median(),inplace=True)
df['Wind_Speed_kmh'].fillna(df['Wind_Speed_kmh'].median(),inplace=True)
df['Drainage_Capacity'].fillna(df['Drainage_Capacity'].median(),inplace=True)
df['Elevation_m'].fillna(df['Elevation_m'].median(),inplace=True)
df['Flood_Risk_Index'].fillna(df['Flood_Risk_Index'].median(),inplace=True)
# Out:
# /tmp/ipykernel_12083/1021816447.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Rainfall_mm'].fillna(df['Rainfall_mm'].median(),inplace=True)
# /tmp/ipykernel_12083/1021816447.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df['Region'].fillna(df['Region'].mode()[0],inplace=True)
df['Season'].fillna(df['Season'].mode()[0],inplace=True)
df['Previous_Floods'].fillna(df['Previous_Floods'].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_12083/645313706.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Region'].fillna(df['Region'].mode()[0],inplace=True)
# /tmp/ipykernel_12083/645313706.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# Rainfall_mm          0
# River_Level_m        0
# Soil_Moisture_%      0
# Temperature_C        0
# Humidity_%           0
# Wind_Speed_kmh       0
# Drainage_Capacity    0
# Elevation_m          0
# Region               0
# Season               0
# Flood_Risk_Index     0
# Previous_Floods      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(250)

# %%
df.shape
# Out:
# (5250, 12)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (5000, 12)

# %%
plt.hist(df['Flood_Risk_Index'])
plt.show()

# %%
sns.histplot(df['Humidity_%'],kde=True)
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.countplot(x=df['Region'])
plt.title("REGION COUNT")
plt.xticks(rotation=45)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rainfall_mm        5000 non-null   float64
#  1   River_Level_m      5000 non-null   float64
#  2   Soil_Moisture_%    5000 non-null   float64
#  3   Temperature_C      5000 non-null   float64
#  4   Humidity_%         5000 non-null   float64
#  5   Wind_Speed_kmh     5000 non-null   float64
#  6   Drainage_Capacity  5000 non-null   float64
#  7   Elevation_m        5000 non-null   float64
#  8   Region             5000 non-null   object
#  9   Season             5000 non-null   object
#  10  Flood_Risk_Index   5000 non-null   float64
#  11  Previous_Floods    5000 non-null   float64
# dtypes: float64(10), object(2)
# memory usage: 507.8+ KB

# %%
print(df['Region'].unique())
# Out:
# ['West' 'East' 'South' 'North']

# %%
print(df['Season'].unique())
# Out:
# ['Summer' 'Monsoon' 'Winter']

# %%
df['Region'].replace(['West','East','South','North'],[0,1,2,3],inplace=True)
# Out:
# /tmp/ipykernel_12083/2040836212.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Region'].replace(['West','East','South','North'],[0,1,2,3],inplace=True)
# /tmp/ipykernel_12083/2040836212.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df['Season'].replace(['Summer','Monsoon','Winter'],[0,1,2],inplace=True)
# Out:
# /tmp/ipykernel_12083/1059674614.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Season'].replace(['Summer','Monsoon','Winter'],[0,1,2],inplace=True)
# /tmp/ipykernel_12083/1059674614.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rainfall_mm        5000 non-null   float64
#  1   River_Level_m      5000 non-null   float64
#  2   Soil_Moisture_%    5000 non-null   float64
#  3   Temperature_C      5000 non-null   float64
#  4   Humidity_%         5000 non-null   float64
#  5   Wind_Speed_kmh     5000 non-null   float64
#  6   Drainage_Capacity  5000 non-null   float64
#  7   Elevation_m        5000 non-null   float64
#  8   Region             5000 non-null   int64
#  9   Season             5000 non-null   int64
#  10  Flood_Risk_Index   5000 non-null   float64
#  11  Previous_Floods    5000 non-null   float64
# dtypes: float64(10), int64(2)
# memory usage: 507.8 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
corr_matrix=df.corr()
sns.heatmap(corr_matrix,annot=True,fmt='0.01f',cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
df.drop([ 'Soil_Moisture_%'],axis=1,inplace=True)

# %%
price_corr=df.corr()['Flood_Risk_Index']
price_corr=price_corr.drop('Flood_Risk_Index')

sns.heatmap(price_corr.to_frame(),annot=True,fmt='.2f',cmap='coolwarm',cbar=True,annot_kws={'size':10})
plt.title("Correlation Between Flood_Risk_Index and other Features")
plt.show()

# %%
df.drop(['Temperature_C','Region'],axis=1,inplace=True)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (5000, 9)

# %%
def remove_outliers_iqr(df,exclude_column):
  for col in df.columns:
    if col== exclude_column:
      continue
    Q1=df[col].quantile(0.25)
    Q3=df[col].quantile(0.75)
    IQR=Q3-Q1
    lower_bound=Q1-1.5*IQR
    upper_bound=Q3+1.5*IQR

    df=df[(df[col] >=lower_bound) & (df[col] <= upper_bound)]
  return df

df_cleaned=remove_outliers_iqr(df,exclude_column='Flood_Risk_Index')
df=df_cleaned

# %%
df.shape
# Out:
# (4625, 9)

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler


features=['Rainfall_mm', 'River_Level_m', 'Humidity_%', 'Wind_Speed_kmh',
       'Drainage_Capacity', 'Elevation_m', 'Season','Previous_Floods']


scaler=MinMaxScaler()


scaled_data=scaler.fit_transform(df[features])


scaled_df=pd.DataFrame(scaled_data,columns=features)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
import pandas as pd

x=df[['Rainfall_mm', 'River_Level_m', 'Humidity_%', 'Wind_Speed_kmh',
       'Drainage_Capacity', 'Elevation_m', 'Season','Previous_Floods']]
y=df['Flood_Risk_Index']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

model=LinearRegression()
model.fit(x_train,y_train)

y_pred=model.predict(x_test)
accuracy=model.score(x_test,y_test)
print(f'Baseline model accuracy:{accuracy:.2f}')
# Out:
# Baseline model accuracy:0.89

# %% [markdown]
# # HYPER PARAMETER TUNING

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
from sklearn.metrics import mean_squared_error, mean_absolute_error

model=Sequential()
model.add(Dense(108,input_shape=(8,),activation='relu'))# Hidden Layer 1
model.add(Dense(60,activation='relu'))# Hidden Layer 2
model.add(Dense(42,activation='relu'))# Hidden Layer 3

model.add(Dense(1,))# Output Layer


model.compile(optimizer=Adam(learning_rate=0.1),
        loss='mean_squared_error')

model.fit(x_train,y_train,epochs=30)

# Predict using your model
y_pred = model.predict(x_test)

# Calculate MSE and MAE
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"Predictions: {y_pred.flatten()}")
print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
# Out:
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 195901.7344
# Epoch 2/30
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 169.9582
# Epoch 3/30
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 175.3297
# Epoch 4/30
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 187.5264
# Epoch 5/30
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 166.0905
# Epoch 6/30
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 188.7310
# Epoch 7/30
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 156.5485
# Epoch 8/30
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 205.8927
# Epoch 9/30
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 152.7169
# ...
